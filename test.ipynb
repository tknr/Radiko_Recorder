# %%
import radiko_recorder

# %%
try:
    radiko_recorder.main(['-h'])
except SystemExit:
    pass
# Out:
# usage: ipykernel_launcher.py [-h] [-a AREA_ID] [-s]
#                              [station_id] [start_time] [duration_minutes]
#
# Radiko Recorder
#
# positional arguments:
#   station_id            Station ID
#   start_time            Start time (YYYYMMDDHHMMSS)
#   duration_minutes      Duration (minutes)
#
# options:
#   -h, --help            show this help message and exit
#   -a AREA_ID, --area_id AREA_ID
#                         Area ID (JP13, JP27, etc.)
#   -s, --station_list    Show station list

# %%
radiko_recorder.main(['-a', 'JP13', '-s'])
# Out:
# TBS: TBSラジオ
# QRR: 文化放送
# LFR: ニッポン放送
# RN1: ラジオNIKKEI第1
# RN2: ラジオNIKKEI第2
# INT: interfm
# FMT: TOKYO FM
# FMJ: J-WAVE
# JORF: ラジオ日本
# BAYFM78: BAYFM78
# NACK5: NACK5
# YFM: ＦＭヨコハマ
# IBS: LuckyFM 茨城放送
# JOAK: NHKラジオ第1（東京）
# JOAK-FM: NHK-FM（東京）

# %%
radiko_recorder.main(['-a', 'JP13', 'FMT', '20241120120000', '30'])
# Out:
# 2024-11-21 02:04:51 INFO     radiko_recorder.recorder Recording output\FMT_20241121020449.aac...
# 2024-11-21 02:05:09 INFO     radiko_recorder.recorder Successfully recorded output\FMT_20241121020449.aac
